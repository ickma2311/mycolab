# %% [markdown]
# <a href="https://colab.research.google.com/github/ickma2311/mycolab/blob/main/Roadmap/Data_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2025-05-19 at 10.34.22 AM.png](data:image/png;base64,...)
